# %% [markdown]
# # 1.인구 피라미드

# %% [markdown]
# ## 남자 데이터 정의

# %%
import pandas as pd
# file_name = '201108_201108_연령별인구현황_월간.xlsx'
file_name = '202112_202112_연령별인구현황_월간.xlsx'
df_m = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,E:Y')
df_m
# Out:
#               0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국         785,425  1,142,373  1,215,920  1,215,429  1,624,175  1,867,507
# 서울특별시      126,059    173,705    188,872    198,819    285,890    398,640
# 부산광역시       45,023     67,721     68,411     68,668     99,852    115,518
# 대구광역시       34,110     51,870     55,230     58,660     79,574     84,910
# 인천광역시       45,744     65,810     70,252     69,138     92,148    111,686
# 광주광역시       23,167     35,349     38,702     40,155     53,585     54,196
# 대전광역시       22,336     32,959     35,910     37,617     51,291     58,373
# 울산광역시       18,720     28,582     29,477     28,266     36,880     40,708
# 세종특별자치시     10,149     13,835     13,145      9,936      9,203     10,525
# 경기도        231,277    331,462    344,926    333,137    436,755    511,068
# 강원도         21,686     29,920     33,876     35,728     49,764     48,980
# 충청북도        24,730     34,999     38,127     37,910     50,402     57,952
# ...

# %%
df_m.head(3)
# Out:
#             0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       785,425  1,142,373  1,215,920  1,215,429  1,624,175  1,867,507
# 서울특별시    126,059    173,705    188,872    198,819    285,890    398,640
# 부산광역시     45,023     67,721     68,411     68,668     99,852    115,518
#
#             30~34세     35~39세     40~44세     45~49세   ...       55~59세  \
# 행정기관                                                  ...
# 전국       1,675,607  1,797,104  2,030,491  2,119,757   ...    2,087,512
# 서울특별시      367,125    351,638    361,658    371,713   ...      348,512
# 부산광역시      100,304    107,643    126,413    127,096   ...      131,866
#
#             60~64세     65~69세   70~74세   75~79세   80~84세   85~89세  90~94세  \
# 행정기관
# 전국       2,046,089  1,462,656  986,553  696,848  457,975  196,253  49,809
# 서울특별시      343,867    263,247  182,384  134,124   83,319   33,205   8,844
# 부산광역시      144,190    114,724   80,220   54,472   32,930   12,164   2,862
#
# ...

# %%
df_m.iloc[0]
# Out:
# 0~4세         785,425
# 5~9세       1,142,373
# 10~14세     1,215,920
# 15~19세     1,215,429
# 20~24세     1,624,175
# 25~29세     1,867,507
# 30~34세     1,675,607
# 35~39세     1,797,104
# 40~44세     2,030,491
# 45~49세     2,119,757
# 50~54세     2,278,787
# 55~59세     2,087,512
# 60~64세     2,046,089
# 65~69세     1,462,656
# 70~74세       986,553
# 75~79세       696,848
# 80~84세       457,975
# 85~89세       196,253
# 90~94세        49,809
# 95~99세         9,042
# 100세 이상        1,372
# Name: 전국  , dtype: object

# %%
df_m.iloc[0] = df_m.iloc[0].str.replace(',','').astype(int) # 1,195,951 -> 1195951(정수형)

# %%
df_m.iloc[0]
# Out:
# 0~4세        785425
# 5~9세       1142373
# 10~14세     1215920
# 15~19세     1215429
# 20~24세     1624175
# 25~29세     1867507
# 30~34세     1675607
# 35~39세     1797104
# 40~44세     2030491
# 45~49세     2119757
# 50~54세     2278787
# 55~59세     2087512
# 60~64세     2046089
# 65~69세     1462656
# 70~74세      986553
# 75~79세      696848
# 80~84세      457975
# 85~89세      196253
# 90~94세       49809
# 95~99세        9042
# 100세 이상       1372
# Name: 전국  , dtype: object

# %% [markdown]
# ## 여자 데이터 정의

# %%
df_w = pd.read_excel(file_name, skiprows=3, index_col='행정기관', usecols='B,AB:AV')
df_w.head(3)
# Out:
#             0~4세       5~9세     10~14세     15~19세     20~24세     25~29세  \
# 행정기관
# 전국       745,044  1,087,508  1,148,276  1,129,691  1,497,147  1,667,094
# 서울특별시    118,479    165,440    179,007    189,438    317,187    420,560
# 부산광역시     42,755     64,112     64,886     64,140     94,834    105,345
#
#             30~34세     35~39세     40~44세     45~49세   ...       55~59세  \
# 행정기관                                                  ...
# 전국       1,540,454  1,710,270  1,962,340  2,054,204   ...    2,020,877
# 서울특별시      368,876    351,640    367,908    379,501   ...      356,790
# 부산광역시       94,194    103,159    122,810    126,072   ...      138,910
#
#             60~64세     65~69세     70~74세   75~79세   80~84세   85~89세   90~94세  \
# 행정기관
# 전국       2,090,660  1,565,307  1,123,159  908,524  743,850  437,403  167,438
# 서울특별시      378,795    300,013    214,185  165,107  115,819   62,666   24,971
# 부산광역시      160,581    129,383     94,891   68,545   51,694   27,003   10,005
#
# ...

# %%
df_m.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.columns = df_m.columns # 컬럼명 동일
df_w.columns
# Out:
# Index(['0~4세', '5~9세', '10~14세', '15~19세', '20~24세', '25~29세', '30~34세',
#        '35~39세', '40~44세', '45~49세', '50~54세', '55~59세', '60~64세', '65~69세',
#        '70~74세', '75~79세', '80~84세', '85~89세', '90~94세', '95~99세', '100세 이상'],
#       dtype='object')

# %%
df_w.iloc[0] = df_w.iloc[0].str.replace(',','').astype(int)

# %%
df_w
# Out:
#               0~4세     5~9세   10~14세   15~19세   20~24세   25~29세   30~34세  \
# 행정기관
# 전국          745044  1087508  1148276  1129691  1497147  1667094  1540454
# 서울특별시      118,479  165,440  179,007  189,438  317,187  420,560  368,876
# 부산광역시       42,755   64,112   64,886   64,140   94,834  105,345   94,194
# 대구광역시       32,247   49,596   51,857   52,790   71,083   73,354   63,176
# 인천광역시       43,010   62,820   66,764   64,977   85,804  101,413   92,694
# 광주광역시       22,182   33,367   36,319   37,228   49,543   49,148   40,737
# 대전광역시       21,135   31,118   33,785   34,863   48,945   50,788   43,392
# 울산광역시       17,804   26,912   27,208   25,039   29,008   30,826   30,653
# 세종특별자치시      9,849   13,230   12,847    9,866    8,325   10,457   13,907
# 경기도        220,307  316,881  328,544  314,398  402,563  447,883  430,285
# 강원도         20,685   28,680   31,519   32,762   39,495   37,185   35,455
# 충청북도        23,522   33,724   35,703   34,671   42,548   43,513   40,664
# ...

# %% [markdown]
# ## 데이터 시각화

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
plt.figure(figsize = (10,7))
plt.barh(df_m.columns, df_m.iloc[0] // 1000) # 가로 막대 그래프, 단위 : 천명
plt.barh(df_w.columns, df_w.iloc[0] // 1000)
plt.show()

# %%
plt.figure(figsize = (10,7))
# plt.title('2011년 08월 전국 대한민국 인구 피라미드')
plt.title('2021년 12월 전국 대한민국 인구 피라미드')
plt.barh(df_m.columns, -df_m.iloc[0] // 1000) # 가로 막대 그래프, 단위 : 천명
plt.barh(df_w.columns, df_w.iloc[0] // 1000)

# 저장
# plt.savefig('2011.08_전국_인구피라미드.png', dpi=100)
plt.savefig('2021.12_전국_인구피라미드.png', dpi=100)

plt.show()
# -df_m.iloc[0] ## 남자 데이터는 왼쪽에
# df_w.iloc[0] ## 여자 데이터는 오른쪽에
