# %% [markdown]
# # 2.축

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
x = [1,2,3]
y = [2,4,8]

# %%
plt.plot(x,y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5,1,'꺽은선 그래프')

# %%
# plt.plot(x,y)
# plt.title('꺽은선 그래프', fontdict = {'family' : 'HYGungSo-Bold', 'size' : 20}) # 개별 폰트 설정(딕셔너리 형태)
# Out:
# Text(0.5,1,'꺽은선 그래프')

# %%
plt.plot(x,y)
plt.xlabel('X축')
plt.ylabel('Y축')
# Out:
# Text(0,0.5,'Y축')

# %%
plt.plot(x,y)
plt.xlabel('X축', color = 'red')
plt.ylabel('Y축', color = '#00aa00')
# Out:
# Text(0,0.5,'Y축')

# %%
# plt.plot(x, y)
# plt.xlabel('X축', color='red', loc='right') # left, center, right
# plt.ylabel('Y축', color='#00aa00', loc='top') # top, center, bottom
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-0886b6792591> in <module>()
#       1 plt.plot(x, y)
# ----> 2 plt.xlabel('X축', color='red', loc='right') # left, center, right
#       3 plt.ylabel('Y축', color='#00aa00', loc='top') # top, center, bottom
#
# C:\ProgramData\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\pyplot.py in xlabel(s, *args, **kwargs)
#    1502     See there for a full parameter description.
#    1503     """
# -> 1504     return gca().set_xlabel(s, *args, **kwargs)
#    1505
#    1506
#
# C:\ProgramData\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\axes\_axes.py in set_xlabel(self, xlabel, fontdict, labelpad, **kwargs)
#     232         if labelpad is not None:
#     233             self.xaxis.labelpad = labelpad
# --> 234         return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#     235
#     236     def get_ylabel(self):
#
# C:\ProgramData\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\axis.py in set_label_text(self, label, fontdict, **kwargs)
#    1560         if fontdict is not None:
#    1561             self.label.update(fontdict)
# -> 1562         self.label.update(kwargs)
#    1563         self.stale = True
#    1564         return self.label
#
# C:\ProgramData\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\text.py in update(self, kwargs)
#     183         sentinel = object()  # bbox can be None, so use another sentinel.
#     184         bbox = kwargs.pop("bbox", sentinel)
# --> 185         super(Text, self).update(kwargs)
#     186         if bbox is not sentinel:
#     187             self.set_bbox(bbox)
#
# C:\ProgramData\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\artist.py in update(self, props)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# C:\ProgramData\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     886         try:
#     887             ret = [_update_property(self, k, v)
# --> 888                    for k, v in props.items()]
#     889         finally:
#     890             self.eventson = store
#
# C:\ProgramData\Anaconda3\envs\deep-learning\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     879                 func = getattr(self, 'set_' + k, None)
#     880                 if not callable(func):
# --> 881                     raise AttributeError('Unknown property %s' % k)
#     882                 return func(v)
#     883
#
# AttributeError: Unknown property loc

# %%
plt.plot(x, y)
plt.xticks([1,2,3])
plt.yticks([3,6,9,12])
plt.show()
