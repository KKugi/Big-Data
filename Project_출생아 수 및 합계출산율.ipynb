# %% [markdown]
# # 2.출생아 수 및 합계 출산율
# 합계 출산율이란 한 여자가 가임기간(15~49세)에 낳을 것으로 기대되는 평균 출생아 수

# %%
import pandas as pd
file_name = 'stat_142801.xls'
df = pd.read_excel(file_name, skiprows = 2, nrows = 2, index_col = 0)
df
# Out:
#            2012     2013     2014     2015     2016     2017     2018  \
# 출생아 수   484.600  436.500  435.400  438.400  406.200  357.800  326.800
# 합계 출산율    1.297    1.187    1.205    1.239    1.172    1.052    0.977
#
#            2019    2020
# 출생아 수   302.700  272.30
# 합계 출산율    0.918    0.84

# %%
df.index
# Out:
# Index(['출생아 수', '합계 출산율'], dtype='object')

# %%
df.index.values
# Out:
# array(['출생아\xa0수', '합계\xa0출산율'], dtype=object)

# %%
df.rename(index = {'출생아\xa0수':'출생아 수','합계\xa0출산율':'합계 출산율'},inplace = True)

# %%
df.index.values
# Out:
# array(['출생아 수', '합계 출산율'], dtype=object)

# %%
df.loc['출생아 수']
# df.iloc[0] # df.rename(index = {'출생아\xa0수':'출생아 수','합계\xa0출산율':'합계 출산율'},inplace = True) 하지 않아도 됨
# Out:
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# Name: 출생아 수, dtype: float64

# %%
df.iloc[1]
# Out:
# 2012    1.297
# 2013    1.187
# 2014    1.205
# 2015    1.239
# 2016    1.172
# 2017    1.052
# 2018    0.977
# 2019    0.918
# 2020    0.840
# Name: 합계 출산율, dtype: float64

# %%
df.T # 데이터 전치
# Out:
#       출생아 수  합계 출산율
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.840

# %%
df = df.T
df
# Out:
#       출생아 수  합계 출산율
# 2012  484.6   1.297
# 2013  436.5   1.187
# 2014  435.4   1.205
# 2015  438.4   1.239
# 2016  406.2   1.172
# 2017  357.8   1.052
# 2018  326.8   0.977
# 2019  302.7   0.918
# 2020  272.3   0.840

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
plt.plot(df.index,df['출생아 수'])
plt.plot(df.index,df['합계 출산율'])

# %%
fig, ax1 = plt.subplots(figsize = (10,7))
ax1.plot(df.index, df['출생아 수'], color = "#ff812d")


# twinx() : x 축을 공유하는 쌍둥이 axis
# twiny() : y 축을 공유하는 쌍듕이 axis

ax2 = ax1.twinx() 
ax2.plot(df.index, df['합계 출산율'], color = "#ffd100")

# %%
fig, ax1 = plt.subplots(figsize = (13,5))
ax1.set_ylabel('출생아 수 (천명)')
ax1.set_ylim(250,750)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = "#ff812d")

# twinx() : x 축을 공유하는 쌍둥이 axis
# twiny() : y 축을 공유하는 쌍듕이 axis

ax2 = ax1.twinx() 
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.set_ylabel('합계 출산율 (가임여성 1명당 명)')
ax2.plot(df.index, df['합계 출산율'], color = "#ffd100")

# %%
df['출생아 수']
# Out:
# 2012    484.6
# 2013    436.5
# 2014    435.4
# 2015    438.4
# 2016    406.2
# 2017    357.8
# 2018    326.8
# 2019    302.7
# 2020    272.3
# Name: 출생아 수, dtype: float64

# %%
df['합계 출산율']
# Out:
# 2012    1.297
# 2013    1.187
# 2014    1.205
# 2015    1.239
# 2016    1.172
# 2017    1.052
# 2018    0.977
# 2019    0.918
# 2020    0.840
# Name: 합계 출산율, dtype: float64

# %% [markdown]
# ###### enumerate
# 반복문 사용 시 몇 번째 반복문인지 확인이 필요할 수 있습니다.이때 사용합니다.
# 인덱스 번호와 컬렉션의 원소를 tuple형태로 반환합니다.

# %%
for idx, val in enumerate(df['출생아 수']):
    print("index : {}, value: {}".format(idx,val))
# Out:
# index : 0, value: 484.6
# index : 1, value: 436.5
# index : 2, value: 435.4
# index : 3, value: 438.4
# index : 4, value: 406.2
# index : 5, value: 357.8
# index : 6, value: 326.8
# index : 7, value: 302.7
# index : 8, value: 272.3

# %%
for idx, val in enumerate(df['합계 출산율']):
    print("index : {}, value : {}".format(idx,val))
# Out:
# index : 0, value : 1.297
# index : 1, value : 1.187
# index : 2, value : 1.205
# index : 3, value : 1.239
# index : 4, value : 1.172
# index : 5, value : 1.052
# index : 6, value : 0.977
# index : 7, value : 0.9179999999999999
# index : 8, value : 0.84

# %%
fig, ax1 = plt.subplots(figsize = (13,5))
ax1.set_ylabel('출생아 수 (천명)')
ax1.set_ylim(250,750)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = "#ff812d")
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val + 12, val, ha = 'center')
    
# twinx() : x 축을 공유하는 쌍둥이 axis
# twiny() : y 축을 공유하는 쌍듕이 axis

ax2 = ax1.twinx() 
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.set_ylabel('합계 출산율 (가임여성 1명당 명)')
ax2.plot(df.index, df['합계 출산율'], color = "#ffd100")

# %%
fig, ax1 = plt.subplots(figsize = (13,5))
ax1.set_ylabel('출생아 수 (천명)')
ax1.set_ylim(250,750)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = "#ff812d")
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val + 12, val, ha = 'center')
    
# twinx() : x 축을 공유하는 쌍둥이 axis
# twiny() : y 축을 공유하는 쌍듕이 axis
# makersize : ms
# linewidth : lw
# markeredgecolor : mec
# markeregdewidth : mew

ax2 = ax1.twinx() 
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.set_ylabel('합계 출산율 (가임여성 1명당 명)')
ax2.plot(df.index, df['합계 출산율'], color = "#ffd100", marker='o', 
         ms = 15, lw = 5, mec = 'w', mew = 3)

# %%
fig, ax1 = plt.subplots(figsize = (13,5))
fig.suptitle('출생아 수 및 합계 출산율')
ax1.set_ylabel('출생아 수 (천명)')
ax1.set_ylim(250,750)
ax1.set_yticks([300,400,500,600])
ax1.bar(df.index, df['출생아 수'], color = "#ff812d")
df['출생아 수'] = round(df['출생아 수'],3)
for idx, val in enumerate(df['출생아 수']):
    ax1.text(idx, val + 12, val, ha = 'center')
    
# twinx() : x 축을 공유하는 쌍둥이 axis
# twiny() : y 축을 공유하는 쌍듕이 axis
# makersize : ms
# linewidth : lw
# markeredgecolor : mec
# markeregdewidth : mew

ax2 = ax1.twinx() 
ax2.set_ylim(0,1.5)
ax2.set_yticks([0,1])
ax2.set_ylabel('합계 출산율 (가임여성 1명당 명)')
ax2.plot(df.index, df['합계 출산율'], color = "#ffd100", marker='o', 
         ms = 15, lw = 5, mec = 'w', mew = 3)
df['합계 출산율'] = round(df['합계 출산율'],3)
for idx, val in enumerate(df['합계 출산율']):
    ax2.text(idx, val + 0.08 ,val ,ha = 'center')
    
    
plt.savefig('출생아 수 및 합계 출산율.png', dpi=100)
plt.show()
